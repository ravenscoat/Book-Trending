# %%
import pandas as pd
import numpy as np

# %%
import pickle

# %%
books=pd.read_csv("Books.csv")
ratings=pd.read_csv("Ratings.csv")
Users=pd.read_csv("Users.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16380\3672086752.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv("Books.csv")

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
Users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %% [markdown]
# # Trending Based System

# %% [markdown]
# We are making a trend system based on mean average

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
rating = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
rating.rename(columns={'Book-Rating':'rating'},inplace=True)
rating
# Out:
#                                                Book-Title  rating
# 0        A Light in the Storm: The Civil War Diary of ...       4
# 1                                   Always Have Popsicles       1
# 2                    Apple Magic (The Collector's series)       1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...       1
# 4        Beyond IBM: Leadership Marketing and Finance ...       1
# ...                                                   ...     ...
# 241066                                      Ã?Â?lpiraten.       2
# 241067                     Ã?Â?rger mit Produkt X. Roman.       4
# 241068                                Ã?Â?sterlich leben.       1
# 241069                              Ã?Â?stlich der Berge.       3
# 241070                                  Ã?Â?thique en toc       2
#
# [241071 rows x 2 columns]

# %%
average = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
average.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
average
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
trending=rating.merge(average,on='Book-Title')

# %%
trending
# Out:
#                                                Book-Title  rating  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...       4    2.250000
# 1                                   Always Have Popsicles       1    0.000000
# 2                    Apple Magic (The Collector's series)       1    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...       1    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...       1    0.000000
# ...                                                   ...     ...         ...
# 241066                                      Ã?Â?lpiraten.       2    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.       4    5.250000
# 241068                                Ã?Â?sterlich leben.       1    7.000000
# 241069                              Ã?Â?stlich der Berge.       3    2.666667
# 241070                                  Ã?Â?thique en toc       2    4.000000
#
# [241071 rows x 3 columns]

# %%
trending = trending[trending['rating']>=200].sort_values('avg_rating',ascending=False).head(50)

# %%
trending.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','rating','avg_rating']]
# Out:
#                                             Book-Title          Book-Author  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)        J. K. Rowling
# 3         Harry Potter and the Goblet of Fire (Book 4)        J. K. Rowling
# 5       Harry Potter and the Sorcerer's Stone (Book 1)        J. K. Rowling
# 9    Harry Potter and the Order of the Phoenix (Boo...        J. K. Rowling
# 13       Ender's Game (Ender Wiggins Saga (Paperback))     Orson Scott Card
# 17    Harry Potter and the Chamber of Secrets (Book 2)        J. K. Rowling
# 20   The Hobbit : The Enchanting Prelude to The Lor...       J.R.R. TOLKIEN
# 21   The Fellowship of the Ring (The Lord of the Ri...       J.R.R. TOLKIEN
# 30   Harry Potter and the Sorcerer's Stone (Harry P...        J. K. Rowling
# 32      The Two Towers (The Lord of the Rings, Part 2)       J.R.R. TOLKIEN
# 43                               To Kill a Mockingbird           Harper Lee
# ...

# %%
TRENDING=trending.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','rating','avg_rating']]

# %%
import pickle

# Dump the TRENDING dataframe into a pickle file
with open('trending_books.pkl', 'wb') as file:
    pickle.dump(TRENDING, file)
